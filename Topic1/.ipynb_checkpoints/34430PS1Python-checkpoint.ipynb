# %% [markdown]
# # ECON 34430 Problem Set 1

# %%
# Standard Python Imports

import numpy as np
import pandas as pd
from numba import njit
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib
import statsmodels.api as sm
import math
from scipy.stats import norm
from random import choices
from numpy import matlib
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import connected_components
from scipy.stats import mode
from scipy.sparse import identity
from scipy.sparse.linalg import inv as spinv
from scipy.sparse.linalg import spsolve as spsolve
from numpy.linalg import eig

inv, ax, randint = np.linalg.inv, np.newaxis, np.random.randint
repmat, rand = np.matlib.repmat, np.random.rand

# %% [markdown]
# ## Constructing Employer-Employee Matched Data

# %%
param = dict()
param['nk'] = 30 # Number of firm types
param['nl'] = 10 # Numer of worker types

param['α_σ'], param['ψ_σ'] = 1, 1 # Volatility of worker and firm effects

param['λ'] = 0.05 # Probability of moving firms

param['csort'] = 0.5 # Sorting effect
param['cnetw'] = 0.2 # Network effect
param['csig']  = 0.5 

param['w_σ'] = 0.2 # Volatility of wage shocks

param['num_time'] = 5   # Number of time periods
param['num_ind'] = 40000  # Number of individuals
param['firm_size'] = 15  # Max number of individuals per firm

# %%
def gen_fixed_effects(param):
    
    nk, nl, α_σ, ψ_σ = param['nk'], param['nl'], param['α_σ'], param['ψ_σ']
    csort, cnetw, csig = param['csort'], param['cnetw'], param['csig'] 

    # Drawing fixed effects
    ψ = norm.ppf(np.linspace(1,nk,nk)/(nk+1)) * ψ_σ
    α = norm.ppf(np.linspace(1,nl,nl)/(nl+1)) * α_σ

    # Generating transition matrices.
    G = norm.pdf((ψ[ax, ax, :] - cnetw * ψ[ax, :, ax] - csort * α[:, ax, ax])/csig)
    G = np.divide(G, G.sum(axis=2)[:, :, ax])

    H = np.ones((nl,nk))/nl
    vec = np.zeros(nk)
    vec[0] = 1
    M = np.zeros((nk,nk))

    for l in range(0,nl):
        S, U = eig(G[l, :, :].T)
        stationary = np.array(U[:, np.where(np.abs(S-1.) < 1e-8)[0][0]].flat)
        stationary = stationary / np.sum(stationary)
        H[l, :] = stationary
        
    return ψ, α, G, H

# %% [markdown]
# ### Simulating a Network

# %%
def simulate_network(param):  

    # Generate fixed effects and transition matrices
    
    ψ, α, G, H = gen_fixed_effects(param)
    
    num_ind, num_time, firm_size = param['num_ind'], param['num_time'], param['firm_size']
    nk, nl, α_σ, ψ_σ, w_σ = param['nk'], param['nl'], param['α_σ'], param['ψ_σ'], param['w_σ'] 
    csort, cnetw, csig, λ = param['csort'], param['cnetw'], param['csig'],  param['λ'] 
    
    within_firm_count = num_ind/(firm_size*nk*num_time)

    network = np.zeros((num_ind,num_time), dtype=int)
    spellcount = np.ones((num_ind,num_time))

    # Random draws of worker types for all individuals in panel
    sim_worker_types = randint(low=1, high=nl, size=num_ind)

    for i in range(0, num_ind):

        l = sim_worker_types[i]
        # At time 1, we draw from H for initial firm
        network[i,0] = choices(range(0,nk),H[l,:])[0]

        for t in range(1,num_time):

            # Hit moving shock
            if rand() < λ:
                network[i,t] = choices(range(0,nk), G[l,network[i,t-1],:])[0]
                spellcount[i,t] = spellcount[i,t-1]+1
            else:
                network[i,t] = network[i,t-1]
                spellcount[i,t] = spellcount[i,t-1]      
                
    # Compiling IDs and timestamps     
    ids = np.reshape(np.outer(range(1,num_ind+1),np.ones(num_time)),(num_time*num_ind,1))
    ids = ids.astype(int)[:,0]
    ts = np.reshape(repmat(range(1,num_time+1),num_ind,1),(num_time*num_ind,1))
    ts = ts.astype(int)[:,0]

    # Compiling worker types
    types = np.reshape(np.outer(sim_worker_types, np.ones(num_time)),(num_time*num_ind,1))
    α_data = α[types.astype(int)][:,0]

    # Compiling firm types
    ψ_data = ψ[np.reshape(network,(num_time*num_ind,1))][:,0]
    k_data = np.reshape(network,(num_time*num_ind,1))[:,0]

    # Compiling spell data
    spell_data = np.reshape(spellcount,(num_time*num_ind,1))[:,0]
    
    # Merging all columns into a dataframe
    data = pd.DataFrame(data={'w_id':ids,'t':ts, 'k': k_data,
                              'α':α_data,'ψ':ψ_data,
                              'spell':spell_data.astype(int)})
    
    # Generating firm IDs
    def draw_fid(freq):

        max_int = np.int(np.maximum(1, freq.sum()/(firm_size * num_time)))
        return np.array(np.random.choice(max_int, size=freq.count()) + 1)
    
    dspell = data.groupby(['w_id', 'spell', 'k']).size().to_frame(name='freq').reset_index()
    dspell['f_id'] = dspell.groupby(['k'])['freq'].transform(draw_fid)
    dspell['f_id'] = dspell.groupby(['k', 'f_id'])['freq'].ngroup()
    dspell['f_id'] = dspell['f_id'] + 1
    
    data = data.merge(dspell, on=['w_id','spell', 'k'])
    
    data['move'] = (data['f_id'] != data['f_id'].shift(+1)) & (data['w_id'] == data['w_id'].shift(+1))
    
    # Computing wages through the AKM formula
    data['wage'] = data['α'] + data['ψ'] + w_σ * norm.rvs(size=num_ind * num_time)
    
    return data

# %%
data = simulate_network(param)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
data
# Out:
#          w_id  t   k         α         ψ  spell  freq  f_id   move      wage
# 0           1  1  19  0.604585  0.372289      1     1  1904  False  0.953498
# 1           1  2   8  0.604585 -0.552443      2     4   329   True  0.183116
# 2           1  3   8  0.604585 -0.552443      2     4   329  False  0.000142
# 3           1  4   8  0.604585 -0.552443      2     4   329  False  0.334272
# 4           1  5   8  0.604585 -0.552443      2     4   329  False -0.055607
# ...       ... ..  ..       ...       ...    ...   ...   ...    ...       ...
# 199995  40000  1  19  0.114185  0.372289      1     5  1924  False  0.838385
# 199996  40000  2  19  0.114185  0.372289      1     5  1924  False  0.583613
# 199997  40000  3  19  0.114185  0.372289      1     5  1924  False  0.450456
# 199998  40000  4  19  0.114185  0.372289      1     5  1924  False  0.417344
# 199999  40000  5  19  0.114185  0.372289      1     5  1924  False  0.593435
#
# [200000 rows x 10 columns]

# %% [markdown]
# # This is Where Arjun's Set-Up Code Ends and Our Assignment Begins

# %% [markdown]
# # Question 1

# %%
### Print the average number of workers and movers per time unit per firm ###
print((data.groupby(by=["f_id", "t"])["w_id"].count()).mean(),
      data[data['move'] == True].groupby(by=["f_id", "t"])["w_id"].count().mean())
# Out:
# 15.088645794039985 1.4264521894548705

# %% [markdown]
# # Question 2

# %%
### Group average wages for each firms ###

### Collapse ###
firm = data.groupby(by=["f_id"])["wage"].mean().reset_index()
firm.head()

### Retrieve Quantiles ###
quants = firm["wage"].quantile([.25,.50,.75])
print(quants)

### Assign Quantiles ### 
firm.loc[firm["wage"] <= np.quantile(quants,.25), "Quantile"] = 1
firm.loc[(firm["wage"] <= np.quantile(quants,.50)) & (firm["wage"] > np.quantile(quants,.25)), "Quantile"] = 2
firm.loc[(firm["wage"] <= np.quantile(quants,.75)) & (firm["wage"] > np.quantile(quants,.50)), "Quantile"] = 3
firm.loc[(firm["wage"] > np.quantile(quants,.75)), "Quantile"] = 4
firm = firm.rename(columns={"wage": "firm_mean_wage"})
# Out:
# 0.25   -0.489679
# 0.50    0.183752
# 0.75    0.892441
# Name: wage, dtype: float64

# %%
### Lead and Lag the Wages ###
# These can almost surely be condensed again #
for i in range(1,3):
    variablename = "lag"+str(i)+"wage"
    data[variablename] = data["wage"].shift(periods = i)
    data.loc[data["t"]==i, variablename] = np.nan
data.loc[data["t"]==1, "lag2wage"] = np.nan

for i in range(1,3):
    variablename = "lead"+str(i)+"wage"
    data[variablename] = data["wage"].shift(periods = -i)
    data.loc[data["t"]==6-i, variablename] = np.nan
data.loc[data["t"]==5, "lead2wage"] = np.nan

# %%
firm
# Out:
#       f_id  firm_mean_wage  Quantile
# 0        1       -2.512063       1.0
# 1        2       -2.101383       1.0
# 2        3       -2.204411       1.0
# 3        4       -2.121419       1.0
# 4        5       -2.236192       1.0
# ...    ...             ...       ...
# 2646  2647        2.704123       4.0
# 2647  2648        2.435717       4.0
# 2648  2649        2.985170       4.0
# 2649  2650        2.957573       4.0
# 2650  2651        3.015231       4.0
#
# [2651 rows x 3 columns]

# %%
### Merge in the Firm Quantiles ###
df = pd.merge(data, firm, on="f_id")

### Reset the index ###
df = df.sort_values(by = ["w_id","t"])
df = df.reset_index(drop = True)

### We will want to also lag the Quantile
df["lagQuantile"] = df["Quantile"].shift(periods = i)
df.loc[df["t"]==i, "lagQuantile"] = np.nan
df.tail(10)
# Out:
#          w_id  t   k         α         ψ  spell  freq  f_id   move      wage  \
# 199990  39999  1  16  1.335178  0.121587      1     5  1479  False  1.391503
# 199991  39999  2  16  1.335178  0.121587      1     5  1479  False  1.533775
# 199992  39999  3  16  1.335178  0.121587      1     5  1479  False  1.335015
# 199993  39999  4  16  1.335178  0.121587      1     5  1479  False  1.314992
# 199994  39999  5  16  1.335178  0.121587      1     5  1479  False  1.548117
# 199995  40000  1  19  0.114185  0.372289      1     5  1924  False  0.838385
# 199996  40000  2  19  0.114185  0.372289      1     5  1924  False  0.583613
# 199997  40000  3  19  0.114185  0.372289      1     5  1924  False  0.450456
# 199998  40000  4  19  0.114185  0.372289      1     5  1924  False  0.417344
# 199999  40000  5  19  0.114185  0.372289      1     5  1924  False  0.593435
#
#         lag1wage  lag2wage  lead1wage  lead2wage  firm_mean_wage  Quantile  \
# 199990       NaN       NaN   1.533775   1.335015        0.242681       3.0
# 199991  1.391503       NaN   1.335015   1.314992        0.242681       3.0
# 199992  1.533775  1.391503   1.314992   1.548117        0.242681       3.0
# 199993  1.335015  1.533775   1.548117        NaN        0.242681       3.0
# 199994  1.314992  1.335015        NaN        NaN        0.242681       3.0
# 199995       NaN       NaN   0.583613   0.450456        0.701155       4.0
# 199996  0.838385       NaN   0.450456   0.417344        0.701155       4.0
# 199997  0.583613  0.838385   0.417344   0.593435        0.701155       4.0
# 199998  0.450456  0.583613   0.593435        NaN        0.701155       4.0
# 199999  0.417344  0.450456        NaN        NaN        0.701155       4.0
#
#         lagQuantile
# 199990          4.0
# 199991          NaN
# 199992          3.0
# 199993          3.0
# 199994          3.0
# 199995          3.0
# 199996          NaN
# 199997          4.0
# 199998          4.0
# 199999          4.0

# %%
trans_wages = df[df["move"]== True].groupby(['Quantile', 'lagQuantile'])["lag2wage", "lag1wage", "wage", "lead1wage", "lead2wage" ].mean()

# %%
plt.plot([-2,-1,0,1,2],trans_wages.iloc[0].values,
         [-2,-1,0,1,2],trans_wages.iloc[4].values,
         [-2,-1,0,1,2],trans_wages.iloc[8].values,
        [-2,-1,0,1,2],trans_wages.iloc[12].values,
         [-2,-1,0,1,2],trans_wages.iloc[3].values, 
         [-2,-1,0,1,2],trans_wages.iloc[7].values,
         [-2,-1,0,1,2],trans_wages.iloc[11].values,
        [-2,-1,0,1,2],trans_wages.iloc[15].values)
plt.title('Event Study ala Card-Heining-Kline', fontsize=8)
plt.legend(["1 to 1", "1 to 2", "1 to 3", "1 to 4", "4 to 1", "4 to 2", "4 to 3", "4 to 4"],loc = "right")

# %% [markdown]
# # Question 3

# %% [markdown]
# # Question 4

# %%
### Lag Firm 1 Period ###
data["lag_f_id"] = data["f_id"].shift(periods = 1)

### Set lag = same firm if period 1, this will assure its dropped in the next step ###
data.loc[data["t"]==1, "lag_f_id"] = data["f_id"]


switches = data[data["lag_f_id"]!=data["f_id"]]


### Create Data Set of Connected Firms... We will merge in and keep 1s ###

connected_unique = switches['f_id'].tolist()
connected_unique = connected_unique + switches['lag_f_id'].tolist()

connected_unique = list(set(connected_unique))
connected_set = pd.DataFrame(connected_unique, columns = ["f_id"])

connected_set["connected"] = 1

df_connected = pd.merge(df, connected_set, on="f_id")
df_connected = df_connected[df_connected["connected"]==1]
### Reset the index ###
df_connected = df_connected.sort_values(by = ["w_id","t"])
df_connected = df_connected.reset_index(drop = True)

### Now I print the tail to show if we lost any in the connection.
### I actually lose about 200 obs when I ran this last 

df_connected.tail(10)
# Out:
#          w_id  t   k         α         ψ  spell  freq  f_id   move      wage  \
# 199430  39999  1  16  1.335178  0.121587      1     5  1479  False  1.391503
# 199431  39999  2  16  1.335178  0.121587      1     5  1479  False  1.533775
# 199432  39999  3  16  1.335178  0.121587      1     5  1479  False  1.335015
# 199433  39999  4  16  1.335178  0.121587      1     5  1479  False  1.314992
# 199434  39999  5  16  1.335178  0.121587      1     5  1479  False  1.548117
# 199435  40000  1  19  0.114185  0.372289      1     5  1924  False  0.838385
# 199436  40000  2  19  0.114185  0.372289      1     5  1924  False  0.583613
# 199437  40000  3  19  0.114185  0.372289      1     5  1924  False  0.450456
# 199438  40000  4  19  0.114185  0.372289      1     5  1924  False  0.417344
# 199439  40000  5  19  0.114185  0.372289      1     5  1924  False  0.593435
#
#         lag1wage  lag2wage  lead1wage  lead2wage  firm_mean_wage  Quantile  \
# 199430       NaN       NaN   1.533775   1.335015        0.242681       3.0
# 199431  1.391503       NaN   1.335015   1.314992        0.242681       3.0
# 199432  1.533775  1.391503   1.314992   1.548117        0.242681       3.0
# 199433  1.335015  1.533775   1.548117        NaN        0.242681       3.0
# 199434  1.314992  1.335015        NaN        NaN        0.242681       3.0
# 199435       NaN       NaN   0.583613   0.450456        0.701155       4.0
# 199436  0.838385       NaN   0.450456   0.417344        0.701155       4.0
# 199437  0.583613  0.838385   0.417344   0.593435        0.701155       4.0
# 199438  0.450456  0.583613   0.593435        NaN        0.701155       4.0
# 199439  0.417344  0.450456        NaN        NaN        0.701155       4.0
#
#         lagQuantile  connected
# 199430          4.0          1
# 199431          NaN          1
# 199432          3.0          1
# 199433          3.0          1
# 199434          3.0          1
# 199435          3.0          1
# 199436          NaN          1
# 199437          4.0          1
# 199438          4.0          1
# 199439          4.0          1

# %% [markdown]
# # Question 5

# %%
### Columns for work / iteration ###
old_mse = 20000000
mse = 10000000
mse_change = 100000000000
count = df_connected["w_id"].count()


df_connected["alpha_hat"] = df_connected["α"]
df_connected["psi_hat"] = df_connected["ψ"]
df_connected["wage_hat"] = 0
df_connected["wage_sq_error"] = 100.00

df_connected["wage_lessfirm"] = df_connected["wage"] - df_connected["ψ"]
df_connected["wage_lesswork"] = df_connected["wage"] - df_connected["α"]

### Get iterating number ###
w_id_max = df_connected["w_id"].max() + 1
f_id_max = df_connected["f_id"].max() + 1

df_connected.head(10)
# Out:
#    w_id  t   k         α         ψ  spell  freq  f_id   move      wage  ...  \
# 0     1  1  19  0.604585  0.372289      1     1  1904  False  0.953498  ...
# 1     1  2   8  0.604585 -0.552443      2     4   329   True  0.183116  ...
# 2     1  3   8  0.604585 -0.552443      2     4   329  False  0.000142  ...
# 3     1  4   8  0.604585 -0.552443      2     4   329  False  0.334272  ...
# 4     1  5   8  0.604585 -0.552443      2     4   329  False -0.055607  ...
# 5     2  1  15 -0.114185  0.040441      1     5  1302  False  0.197220  ...
# 6     2  2  15 -0.114185  0.040441      1     5  1302  False  0.250523  ...
# 7     2  3  15 -0.114185  0.040441      1     5  1302  False  0.042712  ...
# 8     2  4  15 -0.114185  0.040441      1     5  1302  False  0.086605  ...
# 9     2  5  15 -0.114185  0.040441      1     5  1302  False  0.017939  ...
#
#    firm_mean_wage  Quantile  lagQuantile  connected  alpha_hat   psi_hat  \
# 0        0.667040       4.0          NaN          1   0.604585  0.372289
# 1       -0.851665       1.0          NaN          1   0.604585 -0.552443
# 2       -0.851665       1.0          4.0          1   0.604585 -0.552443
# 3       -0.851665       1.0          1.0          1   0.604585 -0.552443
# 4       -0.851665       1.0          1.0          1   0.604585 -0.552443
# 5        0.204738       3.0          1.0          1  -0.114185  0.040441
# 6        0.204738       3.0          NaN          1  -0.114185  0.040441
# 7        0.204738       3.0          3.0          1  -0.114185  0.040441
# 8        0.204738       3.0          3.0          1  -0.114185  0.040441
# 9        0.204738       3.0          3.0          1  -0.114185  0.040441
#
#    wage_hat  wage_sq_error  wage_lessfirm  wage_lesswork
# 0         0          100.0       0.581209       0.348913
# 1         0          100.0       0.735559      -0.421469
# 2         0          100.0       0.552584      -0.604443
# 3         0          100.0       0.886715      -0.270313
# 4         0          100.0       0.496836      -0.660192
# 5         0          100.0       0.156779       0.311405
# 6         0          100.0       0.210083       0.364709
# 7         0          100.0       0.002272       0.156898
# 8         0          100.0       0.046165       0.200791
# 9         0          100.0      -0.022502       0.132124
#
# [10 rows x 24 columns]

# %%
mse_change = 100000

while mse_change > .000000001:
    ### Loops per request ###
    for w in range(1, w_id_max):
         ### Gets mean of wages-psi hat, within worker
        worker_mean = df_connected[df_connected['w_id'] == w]['wage_lessfirm'].mean()
        if worker_mean == np.nan:
            continue
        ### Replaces alpha_hat with that mean ###
        df_connected.loc[df_connected["w_id"] == w, "alpha_hat"] = worker_mean

    for f in range(1, f_id_max):
        ### Gets mean of wages-alpha hat, within firm
        firm_mean = df_connected[df_connected['f_id'] == f]['wage_lesswork'].mean()
        if firm_mean == np.nan:
            continue
        ### Replaces psi_hat with that mean ###
        df_connected.loc[df_connected["f_id"] == f, "psi_hat"] = firm_mean
    
    ### Update the wages less FE ###
    df_connected['wage_lessfirm'] = df_connected['wage'] - df_connected['psi_hat']
    df_connected['wage_lesswork'] = df_connected['wage'] - df_connected['alpha_hat']

    ### Create new wage hat ###
    df_connected["wage_hat"] = df_connected['alpha_hat'] + df_connected['psi_hat']
    
    ### Calc MSE and Distance ###
    df_connected["wage_sq_error"] = (df_connected["wage"] - df_connected["wage_hat"])*(df_connected["wage"] - df_connected["wage_hat"])
   
    old_mse = mse
    
    mse = df_connected["wage_sq_error"].sum() / count
    
    if mse_change > old_mse - mse:
        mse_change = old_mse - mse
        print(mse_change)
    else:
        print("Error!")
        break
# Out:
# 2.6164447790445744e-05
# 2.4090503865904778e-05
# 2.2226296048741268e-05
# 2.0546610237578977e-05
# 1.9029682178255125e-05
# 1.7656674057509036e-05
# 1.641123773343106e-05
# 1.5279149129431013e-05
# 1.4248001274835831e-05
# 1.3306945832299022e-05
# 1.2446474836828869e-05
# 1.1658235885080026e-05
# 1.0934875230822483e-05
# 1.0269904228976667e-05
# 9.657585368139099e-06
# 9.092834780607961e-06
# 8.571138650666221e-06
# 8.088481373326462e-06
# 7.641283673302801e-06
# 7.226349186609249e-06
# 6.8408182485740765e-06
# 6.482127833204454e-06
# 6.147976754043716e-06
# 5.8362953757745695e-06
# 5.5452192003827006e-06
# 5.2730657886107535e-06
# 5.018314558340176e-06
# 4.77958906872078e-06
# 4.555641456772952e-06
# 4.345338741287841e-06
# 4.147650748985432e-06
# 3.961639453389787e-06
# 3.7864495453648894e-06
# 3.6213000799978357e-06
# 3.465477064756861e-06
# 3.3183268732528415e-06
# 3.1792503834560115e-06
# 3.047697752819878e-06
# 2.9231637547130762e-06
# 2.805183609400075e-06
# 2.693329252304033e-06
# 2.587205988842378e-06
# 2.486449491634346e-06
# 2.3907231020067754e-06
# 2.2997154008677634e-06
# 2.2131380202003448e-06
# 2.1307236683018593e-06
# 2.052224345780451e-06
# 1.9774097320679473e-06
# 1.9060657243594181e-06
# 1.8379931128742477e-06
# 1.7730063786858263e-06
# 1.7109326011788273e-06
# 1.6516104642261276e-06
# 1.5948893512460205e-06
# 1.5406285202787529e-06
# 1.4886963508528583e-06
# 1.438969656583633e-06
# 1.3913330559195414e-06
# 1.3456783967552566e-06
# 1.3019042287981675e-06
# 1.2599153200731905e-06
# 1.2196222127433543e-06
# 1.1809408151930434e-06
# 1.1437920269807833e-06
# 1.1081013933655903e-06
# 1.0737987873529753e-06
# 1.0408181162421815e-06
# 1.0090970510787112e-06
# 9.785767766529174e-07
# 9.492017604487146e-07
# 9.209195389117686e-07
# 8.936805196146924e-07
